# %%
# Veri Seti Hikayesi:
# Elektronik kategorisindeki en fazla yorum alan ürünün kullanıcı puanları ve yorumları vardır.

# Değişkenler:
# reviewerID - ID of the reviewer, e.g. A2SUAM1J3GNN3B
# asin - ID of the product, e.g. 0000013714
# reviewerName - name of the reviewer
# helpful - helpfulness rating of the review, e.g. 2/3
# reviewText - text of the review
# overall - rating of the product
# summary - summary of the review
# unixReviewTime - time of the review (unix time)
# reviewTime - time of the review (raw)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import math
import scipy.stats as st
import sys

# %%
#Görev 1: Average Rating'i Güncel Yorumlara Göre Hesaplamak ve Var Olan Average Rating ile Kıyaslamak.

# Paylaşılan veri setinde kullanıcılar bir ürüne puanlar vermiş ve yorumlar yapmıştır.
# Bu görevde amacımız verilen puanları tarihe göre ağırlıklandırarak değerlendirmek.
# İlk ortalama puan ile elde edilecek tarihe göre ağırlıklı puanın karşılaştırılması gerekmektedir.

# %%
#Ürünün ortalama puanı

df = pd.read_csv("amazon_review.csv")
df["overall"].mean()
# Out:
# 4.587589013224822

# %%
# Son zamanlardaki trendin kaçırılma durumu var. Örneğin Ürünle iligili kullanıldıktan sonra çeşitli arzaların ortaya çıkması gibi.
# Bu durumda tarihe göre bir ağırlıklandırma yapıp yeni bir rating hesaplanabilir. Böylece son zamanlardaki pozitif trend veya
# negait trend durumu yakalanabilir duruma geliyor olacakatır.

# %%
# Tarihe göre ağırlıklandırma

# Tarihlere göre ağırlıklı puan hesabı yapabilmek için:
#   - reviewTime değişkenini tarih değişkeni olarak tanıtmanız
#   - reviewTime'ın max değerini current_date olarak kabul etmeniz
#   - her bir puan-yorum tarihi ile current_date'in farkını gün cinsinden ifade ederek yeni değişken oluşturmanız
#   - ve gün cinsinden ifade edilen değişkeni quantile fonksiyonu ile 4'e bölüp (3 çeyrek verilirse 4 parça çıkar)
#   - çeyrekliklerden gelen değerlere göre ağırlıklandırma yapmanız gerekir.
#   - örneğin q1 = 12 ise ağırlıklandırırken 12 günden az süre önce yapılan yorumların ortalamasını alıp bunlara
#   - yüksek ağırlık vermek gibi.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4915 entries, 0 to 4914
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   reviewerID      4915 non-null   object
#  1   asin            4915 non-null   object
#  2   reviewerName    4914 non-null   object
#  3   helpful         4915 non-null   object
#  4   reviewText      4914 non-null   object
#  5   overall         4915 non-null   float64
#  6   summary         4915 non-null   object
#  7   unixReviewTime  4915 non-null   int64
#  8   reviewTime      4915 non-null   object
#  9   day_diff        4915 non-null   int64
#  10  helpful_yes     4915 non-null   int64
#  11  total_vote      4915 non-null   int64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 460.9+ KB

# %%
# day_diff: yorum sonrası ne kadar gün geçmiş
df['reviewTime'] = pd.to_datetime(df['reviewTime'], dayfirst=True)
current_date = pd.to_datetime(str(df['reviewTime'].max()))
df["day_diff"] = (current_date - df['reviewTime']).dt.days

# %%
# day_diff değişkeninin çeyrek değerlerini elde etme:
a = df["day_diff"].quantile(0.25)
b = df["day_diff"].quantile(0.50)
c = df["day_diff"].quantile(0.75)

# %%
# a,b,c değerlerine göre ağırlıklı puanı hesaplama:
df.loc[df["day_diff"] <= a, "overall"].mean() * 30 / 100 + \
df.loc[(df["day_diff"] > a) & (df["day_diff"] <= b), "overall"].mean() * 26 / 100 + \
df.loc[(df["day_diff"] > b) & (df["day_diff"] <= c), "overall"].mean() * 24 / 100 + \
df.loc[(df["day_diff"] > c), "overall"].mean() * 20 / 100
# Out:
# 4.600583941300071

# %%
# Görev 2: Ürün için Ürün Detay Sayfasında Görüntülenecek 20 Review'i Belirleyiniz.
# Adım 1. helpful_no Değişkenini Üretiniz
###################################################

# Not:
# total_vote bir yoruma verilen toplam up-down sayısıdır.
# up, helpful demektir.
# veri setinde helpful_no değişkeni yoktur, var olan değişkenler üzerinden üretilmesi gerekmektedir.

df["helpful_no"] = df["total_vote"] - df["helpful_yes"]
df = df[["reviewerName", "overall", "summary", "helpful_yes", "helpful_no", "total_vote", "reviewTime"]]
df.head()
# Out:
#    reviewerName  overall                                 summary  helpful_yes  \
# 0           NaN      4.0                              Four Stars            0
# 1          0mie      5.0                           MOAR SPACE!!!            0
# 2           1K3      4.0               nothing to really say....            0
# 3           1m2      5.0  Great buy at this price!!!  *** UPDATE            0
# 4  2&amp;1/2Men      5.0                        best deal around            0
#
#    helpful_no  total_vote reviewTime
# 0           0           0 2014-07-23
# 1           0           0 2013-10-25
# 2           0           0 2012-12-23
# 3           0           0 2013-11-21
# 4           0           0 2013-07-13

# %%
# Adım 2. score_pos_neg_diff, score_average_rating ve wilson_lower_bound Skorlarını Hesaplayıp Veriye Ekleyiniz

def score_up_down_diff(up, down):
    return up - down

# score_pos_neg_diff
df["score_pos_neg_diff"] = df.apply(lambda x: score_up_down_diff(x["helpful_yes"], x["helpful_no"]), axis=1)

df.sort_values("score_pos_neg_diff", ascending=False).head(20)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#                      reviewerName  overall  \
# 2031         Hyoun Kim "Faluzure"      5.0
# 4212                  SkincareCEO      1.0
# 3449            NLee the Engineer      5.0
# 317       Amazon Customer "Kelly"      1.0
# 3981   R. Sutton, Jr. "RWSynergy"      5.0
# 4596  Tom Henriksen "Doggy Diner"      1.0
# 1835                  goconfigure      5.0
# 4672                      Twister      5.0
# 4306                Stellar Eller      5.0
# 315    Amazon Customer "johncrea"      5.0
# 3807                   R. Heisler      3.0
# 4302                    Stayeraug      5.0
# 93                        Airedad      5.0
# 1609                       Eskimo      5.0
# 1465                     D. Stein      4.0
# 4072                  sb21 "sb21"      5.0
# 2268             Jerry Saperstein      5.0
# 121                        A. Lee      5.0
# 323        Amazon Customer "Milo"      5.0
# 2695                    kinematic      5.0
#
#                                                 summary  helpful_yes  \
# 2031  UPDATED - Great w/ Galaxy S4 & Galaxy Tab 4 10...         1952
# 4212  1 Star reviews - Micro SDXC card unmounts itse...         1568
# 3449  Top of the class among all (budget-priced) mic...         1428
# 317                                 Warning, read this!          422
# 3981  Resolving confusion between "Mobile Ultra" and...          112
# 4596     Designed incompatibility/Don't support SanDisk           82
# 1835                                           I own it           60
# 4672  Super high capacity!!!  Excellent price (on Am...           45
# 4306                                      Awesome Card!           51
# 315   Samsung Galaxy Tab2 works with this card if re...           38
# 3807   Good buy for the money but wait, I had an issue!           22
# 4302                        Perfect with GoPro Black 3+           14
# 93    Very fast class 10 card - and excellent servic...           15
# 1609                  Bet you wish you had one of these            7
# 1465                                           Finally.            7
# 4072               Used for my Samsung Galaxy Tab 2 7.0            6
# 2268                      Incredible simply incredible.            8
# 121                      ready for use on the Galaxy S3            5
# 323                           Working fine in my Note 3            6
# 2695  Works in Samsung Galaxy Tab 2 10.1 after forma...            6
#
#       helpful_no  total_vote reviewTime  score_pos_neg_diff
# 2031          68        2020 2013-01-05                1884
# 4212         126        1694 2013-05-08                1442
# 3449          77        1505 2012-09-26                1351
# 317           73         495 2012-02-09                 349
# 3981          27         139 2012-10-22                  85
# 4596          27         109 2012-09-22                  55
# 1835           8          68 2014-02-28                  52
# 4672           4          49 2014-07-03                  41
# 4306          14          65 2012-09-06                  37
# 315           10          48 2012-08-13                  28
# 3807           3          25 2013-02-27                  19
# 4302           2          16 2014-03-21                  12
# 93             6          21 2012-07-25                   9
# 1609           0           7 2014-03-26                   7
# 1465           0           7 2014-04-14                   7
# 4072           0           6 2012-11-09                   6
# 2268           2          10 2014-03-17                   6
# 121            0           5 2012-05-09                   5
# 323            1           7 2014-01-04                   5
# 2695           1           7 2012-08-09                   5

# %%
def score_average_rating(up, down):
    if up + down == 0:
        return 0
    return up / (up + down)


# score_average_rating
df["score_average_rating"] = df.apply(lambda x: score_average_rating(x["helpful_yes"], x["helpful_no"]), axis=1)

df.sort_values("score_average_rating", ascending=False).head(20)
# Out:
#                      reviewerName  overall  \
# 4277                        S. Q.      5.0
# 2881                   Lou Thomas      5.0
# 1073                   C. Sanchez      5.0
# 445            Apache "Elizabeth"      4.0
# 3923              Rock Your Roots      5.0
# 435                Anthony L cate      5.0
# 2901                         luis      5.0
# 2204                jbwam "jbwam"      2.0
# 2206                      JCBiker      5.0
# 3408         Neng Vang "Neng2012"      5.0
# 4538                       Tim ha      4.0
# 1097          Cyrus C. Cha "moss"      4.0
# 2885   L. P. Nugaliyadda "Pramod"      5.0
# 3418               Ni'anhel Moore      5.0
# 4554                      Tinfoot      5.0
# 1609                       Eskimo      5.0
# 402   Andrew R. Seiler "bookfish"      5.0
# 2226                         JEFE      5.0
# 3901     Roberto K. Cho "chorobe"      4.0
# 3897      Robert K. Harvey "BobH"      2.0
#
#                                                 summary  helpful_yes  \
# 4277                                          Perfect!!            1
# 2881                         Nexus One Loves This Card!            1
# 1073                            Tons of space for phone            1
# 445                                 Amazon Great Prices            1
# 3923                                  What more to say?            1
# 435                              Love the extra storage            1
# 2901                          Awesome and fast  card :)            1
# 2204  Sandisk will replace failures due to bad batch...            1
# 2206                                         Great card            1
# 3408                                 working no problem            1
# 4538                Decent speed for the card this size            1
# 1097                              More space for Note 3            1
# 2885                                         Excellent!            1
# 3418                                        Works Great            1
# 4554                                           PSP 3000            1
# 1609                  Bet you wish you had one of these            7
# 402                    great, works well with galaxy s3            1
# 2226                                       great memory            1
# 3901   Good while it lasted! BUT good customer support!            1
# 3897                                   Poor write speed            1
#
#       helpful_no  total_vote reviewTime  score_pos_neg_diff  \
# 4277           0           1 2012-12-19                   1
# 2881           0           1 2012-01-10                   1
# 1073           0           1 2013-08-13                   1
# 445            0           1 2013-12-18                   1
# 3923           0           1 2013-12-30                   1
# 435            0           1 2012-07-24                   1
# 2901           0           1 2013-05-13                   1
# 2204           0           1 2013-06-14                   1
# 2206           0           1 2013-10-31                   1
# 3408           0           1 2013-07-25                   1
# 4538           0           1 2014-04-25                   1
# 1097           0           1 2013-10-14                   1
# 2885           0           1 2014-03-21                   1
# 3418           0           1 2013-12-31                   1
# 4554           0           1 2014-08-02                   1
# 1609           0           7 2014-03-26                   7
# 402            0           1 2012-09-25                   1
# 2226           0           1 2014-06-16                   1
# 3901           0           1 2013-03-20                   1
# 3897           0           1 2013-11-27                   1
#
#       score_average_rating
# 4277                   1.0
# 2881                   1.0
# 1073                   1.0
# 445                    1.0
# 3923                   1.0
# 435                    1.0
# 2901                   1.0
# 2204                   1.0
# 2206                   1.0
# 3408                   1.0
# 4538                   1.0
# 1097                   1.0
# 2885                   1.0
# 3418                   1.0
# 4554                   1.0
# 1609                   1.0
# 402                    1.0
# 2226                   1.0
# 3901                   1.0
# 3897                   1.0

# %%
def wilson_lower_bound(up, down, confidence=0.95):
    """
    Wilson Lower Bound Score hesapla

    - Bernoulli parametresi p için hesaplanacak güven aralığının alt sınırı WLB skoru olarak kabul edilir.
    - Hesaplanacak skor ürün sıralaması için kullanılır.
    - Not:
    Eğer skorlar 1-5 arasıdaysa 1-3 negatif, 4-5 pozitif olarak işaretlenir ve bernoulli'ye uygun hale getirilebilir.
    Bu beraberinde bazı problemleri de getirir. Bu sebeple bayesian average rating yapmak gerekir.

    Parameters
    ----------
    up: int
        up count
    down: int
        down count
    confidence: float
        confidence

    Returns
    -------
    wilson score: float

    """
    n = up + down
    if n == 0:
        return 0
    z = st.norm.ppf(1 - (1 - confidence) / 2)
    phat = 1.0 * up / n
    return (phat + z * z / (2 * n) - z * math.sqrt((phat * (1 - phat) + z * z / (4 * n)) / n)) / (1 + z * z / n)



df["wilson_lower_bound"] = df.apply(lambda x: wilson_lower_bound(x["helpful_yes"], x["helpful_no"]), axis=1)

df.sort_values("wilson_lower_bound", ascending=False).head(20)
# Out:
#                               reviewerName  overall  \
# 2031                  Hyoun Kim "Faluzure"      5.0
# 3449                     NLee the Engineer      5.0
# 4212                           SkincareCEO      1.0
# 317                Amazon Customer "Kelly"      1.0
# 4672                               Twister      5.0
# 1835                           goconfigure      5.0
# 3981            R. Sutton, Jr. "RWSynergy"      5.0
# 3807                            R. Heisler      3.0
# 4306                         Stellar Eller      5.0
# 4596           Tom Henriksen "Doggy Diner"      1.0
# 315             Amazon Customer "johncrea"      5.0
# 1465                              D. Stein      4.0
# 1609                                Eskimo      5.0
# 4302                             Stayeraug      5.0
# 4072                           sb21 "sb21"      5.0
# 1072                        Crysis Complex      5.0
# 2583                               J. Wong      5.0
# 121                                 A. Lee      5.0
# 1142  Daniel Pham(Danpham_X @ yahoo.  com)      5.0
# 1753                             G. Becker      5.0
#
#                                                 summary  helpful_yes  \
# 2031  UPDATED - Great w/ Galaxy S4 & Galaxy Tab 4 10...         1952
# 3449  Top of the class among all (budget-priced) mic...         1428
# 4212  1 Star reviews - Micro SDXC card unmounts itse...         1568
# 317                                 Warning, read this!          422
# 4672  Super high capacity!!!  Excellent price (on Am...           45
# 1835                                           I own it           60
# 3981  Resolving confusion between "Mobile Ultra" and...          112
# 3807   Good buy for the money but wait, I had an issue!           22
# 4306                                      Awesome Card!           51
# 4596     Designed incompatibility/Don't support SanDisk           82
# 315   Samsung Galaxy Tab2 works with this card if re...           38
# 1465                                           Finally.            7
# 1609                  Bet you wish you had one of these            7
# 4302                        Perfect with GoPro Black 3+           14
# 4072               Used for my Samsung Galaxy Tab 2 7.0            6
# 1072               Works wonders for the Galaxy Note 2!            5
# 2583                  Works Great with a GoPro 3 Black!            5
# 121                      ready for use on the Galaxy S3            5
# 1142                          Great large capacity card            5
# 1753                    Use Nothing Other Than the Best            5
#
#       helpful_no  total_vote reviewTime  score_pos_neg_diff  \
# 2031          68        2020 2013-01-05                1884
# 3449          77        1505 2012-09-26                1351
# 4212         126        1694 2013-05-08                1442
# 317           73         495 2012-02-09                 349
# 4672           4          49 2014-07-03                  41
# 1835           8          68 2014-02-28                  52
# 3981          27         139 2012-10-22                  85
# 3807           3          25 2013-02-27                  19
# 4306          14          65 2012-09-06                  37
# 4596          27         109 2012-09-22                  55
# 315           10          48 2012-08-13                  28
# 1465           0           7 2014-04-14                   7
# 1609           0           7 2014-03-26                   7
# 4302           2          16 2014-03-21                  12
# 4072           0           6 2012-11-09                   6
# 1072           0           5 2012-05-10                   5
# 2583           0           5 2013-08-06                   5
# 121            0           5 2012-05-09                   5
# 1142           0           5 2014-02-04                   5
# 1753           0           5 2012-10-22                   5
#
#       score_average_rating  wilson_lower_bound
# 2031              0.966337            0.957544
# 3449              0.948837            0.936519
# 4212              0.925620            0.912139
# 317               0.852525            0.818577
# 4672              0.918367            0.808109
# 1835              0.882353            0.784651
# 3981              0.805755            0.732136
# 3807              0.880000            0.700442
# 4306              0.784615            0.670334
# 4596              0.752294            0.663595
# 315               0.791667            0.657411
# 1465              1.000000            0.645670
# 1609              1.000000            0.645670
# 4302              0.875000            0.639772
# 4072              1.000000            0.609666
# 1072              1.000000            0.565518
# 2583              1.000000            0.565518
# 121               1.000000            0.565518
# 1142              1.000000            0.565518
# 1753              1.000000            0.565518
